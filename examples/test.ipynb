# %%
# %pip install -e ..
# Out:
# Obtaining file:///home/mk/Developer/torchchronos
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for torchchronos (pyproject.toml) ... done
#   Created wheel for torchchronos: filename=torchchronos-0.0.3.post1-py3-none-any.whl size=3706 sha256=59a9172ddf2c86a9143d04a9c16f2f21aa2ed49a53b49fc5fac0bded614294b6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-28tme8vj/wheels/ae/7b/de/8a2b8087fb1d17217e2d7349f6e1ad77304caa3b57308aa015
# Successfully built torchchronos
# ...
#   Attempting uninstall: torchchronos
#     Found existing installation: torchchronos 0.0.3.post1
#     Uninstalling torchchronos-0.0.3.post1:
#       Successfully uninstalled torchchronos-0.0.3.post1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from torchchronos import download as tcd
from torchchronos.datasets import UCRUEADataset
from torchchronos.typing import DatasetSplit
from pathlib import Path

tcd.download_uea_ucr("AtrialFibrillation", Path("./test_cache"))

dataset = UCRUEADataset(
    ds_name="AtrialFibrillation",
    path=Path("./test_cache"),
    split=DatasetSplit.TEST,
)

next(iter(dataset))
# Out:
# (tensor([[ 0.4199, -0.0593],
#          [ 0.3557, -0.0395],
#          [ 0.2569, -0.0198],
#          ...,
#          [ 0.0494,  0.0445],
#          [ 0.0296,  0.0494],
#          [ 0.0000,  0.0445]]),
#  tensor(0))
